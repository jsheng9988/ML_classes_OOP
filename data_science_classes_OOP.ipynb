# %% [markdown]
# Source: https://towardsdatascience.com/using-classes-for-machine-learning-2ed6c0713305/

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import numpy as np

# %%
data = "weatherHistory.csv"
df1 = pd.read_csv(data)
df1.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
# define Model calss
class Model:
    # def __init__(self, datafile = "weatherHistory.csv"):    # constructor init - initialize data 
    #     self.df = pd.read_csv(datafile)
    
    # define linear regression object in the initialization function
    def __init__(self, datafile = "weatherHistory.csv"):
        self.df = pd.read_csv(datafile)
        self.linear_reg = LinearRegression()
        self.random_forest = RandomForestRegressor() # we can also define another RF model object in Model

    # split the data into train test 
    def split(self, test_size):
        X = np.array(self.df[['Humidity', 'Pressure (millibars)']]) # input
        y = np.array(self.df['Temperature (C)'])
        self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(X, y, 
                                                                                test_size = test_size, 
                                                                                random_state = 42)
        
    # define a fit function 
    def fit(self):
        self.model = self.linear_reg.fit(self.X_train, self.y_train)
    
    # define a predict function
    def predict(self, input_value):
        if input_value == None:
            result = self.linear_reg.predict(self.X_test)
        else:
            result = self.linear_reg.predict(np.array([input_value])) # make prediction on input value
        return result

# %%
if __name__ == 'main': # model_instance as an object, (instance from Model class above)
    model_instance = Model()

# %%
# call the dataframe 
if __name__ == '__main__':
    model_instance = Model()
    print(model_instance.df.head())
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
# call the dataframe 
if __name__ == '__main__':
    model_instance = Model()
    print(model_instance.linear_reg)
# Out:
# LinearRegression()

# %%
# print inspection
if __name__ == '__main__':
    model_instance = Model()
    model_instance.split(0.2)
    print('X_train: ',model_instance.X_train)
    print('y_train',model_instance.y_train)
# Out:
# X_train:  [[9.60000e-01 1.01497e+03]
#  [6.70000e-01 1.01007e+03]
#  [9.70000e-01 1.01024e+03]
#  ...
#  [8.10000e-01 1.01039e+03]
#  [8.20000e-01 1.01244e+03]
#  [9.00000e-01 1.01548e+03]]
# y_train [15.43888889  6.02777778 18.23888889 ...  9.35       19.16111111
#   5.        ]

# %%
# print inspection
if __name__ == '__main__':
    model_instance = Model()
    model_instance.split(0.2)
    # print test predictions 
    model_instance.fit()
    print(model_instance.predict())
    print ('Accuracy: ', model_instance.model.score(model_instance.X_test, model_instance.y_test))
# Out:
# [18.27024238  8.9966463  14.55962648 ... 18.26962999 17.96249378
#  16.41528188]
# Accuracy:  0.3957856046568643

# %%
# predict an input value
if __name__ == '__main__':
    model_instance = Model()
    model_instance.split(0.2)
    # print test predictions 
    model_instance.fit()
    print(model_instance.predict([0.9, 1000]))
# Out:
# [6.83625473]

# %% [markdown]
# # Compiling the whole program

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import numpy as np

# %%
# define Model calss
class Model:
    # define linear regression object in the initialization function
    def __init__(self, datafile = "weatherHistory.csv", model_type = None): # default = None
        self.df = pd.read_csv(datafile)
        
        if model_type == 'rf':
            # self.random_forest = RandomForestRegressor() # we can also define another RF model object in Model
            self.user_defined_model = RandomForestRegressor()
        # if another model
        
        else: 
            # self.linear_reg = LinearRegression()
            self.user_defined_model = LinearRegression()
        

    # split the data into train test 
    def split(self, test_size):
        X = np.array(self.df[['Humidity', 'Pressure (millibars)']]) # input
        y = np.array(self.df['Temperature (C)'])
        self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(X, y, 
                                                                                test_size = test_size, 
                                                                                random_state = 42)
        
    # define a fit function 
    def fit(self):
        self.model = self.user_defined_model.fit(self.X_train, self.y_train)
    
    # define a predict function
    def predict(self, input_value):
        if input_value == None:
            result = self.user_defined_model.predict(self.X_test)
        else:
            result = self.user_defined_model.predict(np.array([input_value])) # make prediction on input value
        return result

# %%
if __name__ == '__main__':
    # model_instance = Model(model_type = 'rf')
    model_instance = Model(model_type = None)
    model_instance.split(0.2)
    # print test predictions 
    model_instance.fit()
    # print(model_instance.predict())
    print ('Accuracy: ', model_instance.model.score(model_instance.X_test, model_instance.y_test))
# Out:
# Accuracy:  0.4480278299290561

# %%
if __name__ == '__main__':
    # model_instance = Model(model_type = 'rf')
    model_instance = Model(model_type = None)
    model_instance.split(0.2)
    # print test predictions 
    model_instance.fit()
    # print(model_instance.predict())
    print ('Accuracy: ', model_instance.model.score(model_instance.X_test, model_instance.y_test))
# Out:
# Accuracy:  0.3957856046568643
